# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/preprocesseddata/Training/fourier1_x.csv
# /kaggle/input/preprocesseddata/Training/fourdays_1.csv
# /kaggle/input/preprocesseddata/Training/yearly_trend.csv
# /kaggle/input/preprocesseddata/Training/access_ohe.csv
# /kaggle/input/preprocesseddata/Training/weekly_trend.csv
# /kaggle/input/preprocesseddata/Training/fourier2_y.csv
# /kaggle/input/preprocesseddata/Training/spider_ohe.csv
# /kaggle/input/preprocesseddata/Training/fourier3_y.csv
# /kaggle/input/preprocesseddata/Training/fourdays_3.csv
# /kaggle/input/preprocesseddata/Training/monthly_trend.csv
# /kaggle/input/preprocesseddata/Training/fourier2_x.csv
# /kaggle/input/preprocesseddata/Training/fourdays_2.csv
# /kaggle/input/preprocesseddata/Training/prj_ohe.csv
# /kaggle/input/preprocesseddata/Training/fourier1_y.csv
# /kaggle/input/preprocesseddata/Training/week_day_ohe.csv
# /kaggle/input/preprocesseddata/Training/rand_trend.csv
# /kaggle/input/preprocesseddata/Training/target.csv
# /kaggle/input/preprocesseddata/Training/fourier3_x.csv

# %%
import numpy as np 
import pandas as pd
from sklearn.metrics import make_scorer
# !pip install xgboost
from xgboost import XGBRegressor
from math import sqrt
from sklearn.model_selection import GridSearchCV
# Out:
# Requirement already satisfied: xgboost in /opt/conda/lib/python3.10/site-packages (2.0.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from xgboost) (1.24.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from xgboost) (1.11.4)

# %%
file_paths = [
    '/kaggle/input/preprocesseddata/Training/access_ohe.csv',
    '/kaggle/input/preprocesseddata/Training/fourdays_1.csv',
    '/kaggle/input/preprocesseddata/Training/fourdays_2.csv',
    '/kaggle/input/preprocesseddata/Training/fourdays_3.csv',
    '/kaggle/input/preprocesseddata/Training/fourier1_x.csv',
    '/kaggle/input/preprocesseddata/Training/fourier2_x.csv',
    '/kaggle/input/preprocesseddata/Training/fourier3_x.csv',
    '/kaggle/input/preprocesseddata/Training/fourier1_y.csv',
    '/kaggle/input/preprocesseddata/Training/fourier2_y.csv',
    '/kaggle/input/preprocesseddata/Training/fourier3_y.csv',
    '/kaggle/input/preprocesseddata/Training/monthly_trend.csv',
    '/kaggle/input/preprocesseddata/Training/prj_ohe.csv',
    '/kaggle/input/preprocesseddata/Training/rand_trend.csv',
    '/kaggle/input/preprocesseddata/Training/spider_ohe.csv',
    '/kaggle/input/preprocesseddata/Training/week_day_ohe.csv',
    '/kaggle/input/preprocesseddata/Training/weekly_trend.csv',
    '/kaggle/input/preprocesseddata/Training/yearly_trend.csv',
    '/kaggle/input/preprocesseddata/Training/target.csv'
]

access_ohe = pd.read_csv(file_paths[0]).values
fourdays_1 = pd.read_csv(file_paths[1]).values
fourdays_2 = pd.read_csv(file_paths[2]).values
fourdays_3 = pd.read_csv(file_paths[3]).values
fourier1_x = pd.read_csv(file_paths[4]).values
fourier2_x = pd.read_csv(file_paths[5]).values
fourier3_x = pd.read_csv(file_paths[6]).values
fourier1_y = pd.read_csv(file_paths[7]).values
fourier2_y = pd.read_csv(file_paths[8]).values
fourier3_y = pd.read_csv(file_paths[9]).values
monthly_trend = pd.read_csv(file_paths[10]).values
prj_ohe = pd.read_csv(file_paths[11]).values
rand_trend = pd.read_csv(file_paths[12]).values
spider_ohe = pd.read_csv(file_paths[13]).values
week_day_ohe = pd.read_csv(file_paths[14]).values
weekly_trend = pd.read_csv(file_paths[15]).values
yearly_trend = pd.read_csv(file_paths[16]).values
target = pd.read_csv(file_paths[17]).values

# %%
data=np.column_stack((week_day_ohe,weekly_trend,fourdays_1,fourdays_2,
                      fourdays_3,prj_ohe,spider_ohe,access_ohe,fourier1_x,
                      fourier2_x,fourier3_x,fourier1_y,fourier2_y,fourier3_y))

# %%
indices = np.random.permutation(data.shape[0]) # Shuffling the indexes of our data

training_idx, test_idx = indices[:int(0.75*data.shape[0])], indices[int(0.75*data.shape[0]):]

x_train,x_test = data[training_idx,:], data[test_idx,:]

y_train,y_test=target[training_idx,:],target[test_idx,:]

# %%
y_train=y_train.reshape(y_train.shape[0])
y_test=y_test.reshape(y_test.shape[0])

# %% [markdown]
# # Training

# %%
def smape(true_values, forecast_values):
    """
    Compute SMAPE (Symmetric Mean Absolute Percentage Error) given the true and forecast values.
    
    Args:
        true_values (numpy.ndarray): Array of true values.
        forecast_values (numpy.ndarray): Array of forecast values.
        
    Returns:
        float: SMAPE value between 0 and 100.
    """
    # Compute absolute difference and sum of absolute values
    abs_difference = np.abs(true_values - forecast_values)
    abs_sum = np.abs(true_values) + np.abs(forecast_values)
    
    # Avoid division by zero
    non_zero_mask = abs_sum != 0
    
    # Compute SMAPE
    smape_value = np.mean(100 * (abs_difference[non_zero_mask] / abs_sum[non_zero_mask]))
    
    return smape_value

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor
from sklearn.metrics import make_scorer

# Define the parameter grid to search
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [5, 10, 20],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0],
}

# Create an instance of XGBRegressor
XGBR = XGBRegressor(verbosity=3, n_jobs=-1)

smape_scorer = make_scorer(smape, greater_is_better=False)

# Create GridSearchCV object
grid_search = GridSearchCV(estimator=XGBR, param_grid=param_grid, scoring=smape_scorer, cv=5, n_jobs=-1, verbose=3)
# Fit the grid search to the data
grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [14:57:05] ======== Monitor (0): HostSketchContainer ========
# [14:57:05] AllReduce: 0.016204s, 1 calls @ 16204us
#
# [14:57:05] MakeCuts: 0.016283s, 1 calls @ 16283us
#
# [14:57:05] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [14:57:26] ======== Monitor (0): Learner ========
# [14:57:26] Configure: 0.001019s, 1 calls @ 1019us
#
# [14:57:26] EvalOneIter: 0.001143s, 50 calls @ 1143us
#
# [14:57:26] GetGradient: 0.096962s, 50 calls @ 96962us
#
# [14:57:26] PredictRaw: 0.001249s, 50 calls @ 1249us
#
# [14:57:26] UpdateOneIter: 20.694s, 50 calls @ 20693988us
#
# [14:57:26] ======== Monitor (0): GBTree ========
# [14:57:26] BoostNewTrees: 20.5642s, 50 calls @ 20564244us
#
# [14:57:26] CommitModel: 9.6e-05s, 50 calls @ 96us
#
# [14:57:26] ======== Monitor (0): HistUpdater ========
# [14:57:26] BuildHistogram: 1.13432s, 200 calls @ 1134321us
#
# [14:57:26] EvaluateSplits: 0.031385s, 250 calls @ 31385us
#
# [14:57:26] InitData: 0.142309s, 50 calls @ 142309us
#
# [14:57:26] InitRoot: 16.3661s, 50 calls @ 16366143us
#
# [14:57:26] LeafPartition: 4.7e-05s, 50 calls @ 47us
#
# [14:57:26] UpdatePosition: 2.04068s, 250 calls @ 2040677us
#
# [14:57:26] UpdatePredictionCache: 0.195394s, 50 calls @ 195394us
#
# [14:57:26] UpdateTree: 19.7161s, 50 calls @ 19716138us
#
# [14:57:26] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8;, score=-62.471 total time=  27.5s
# [14:57:32] ======== Monitor (0): HostSketchContainer ========
# [14:57:32] AllReduce: 0.018064s, 1 calls @ 18064us
#
# [14:57:32] MakeCuts: 0.01816s, 1 calls @ 18160us
#
# [14:57:32] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [14:57:49] ======== Monitor (0): Learner ========
# [14:57:49] Configure: 0.001005s, 1 calls @ 1005us
#
# [14:57:49] EvalOneIter: 0.001142s, 50 calls @ 1142us
#
# [14:57:49] GetGradient: 0.104258s, 50 calls @ 104258us
#
# [14:57:49] PredictRaw: 0.001252s, 50 calls @ 1252us
#
# [14:57:49] UpdateOneIter: 17.053s, 50 calls @ 17052996us
#
# [14:57:49] ======== Monitor (0): GBTree ========
# [14:57:49] BoostNewTrees: 16.9154s, 50 calls @ 16915438us
#
# [14:57:49] CommitModel: 0.000107s, 50 calls @ 107us
#
# [14:57:49] ======== Monitor (0): HistUpdater ========
# [14:57:49] BuildHistogram: 0.580678s, 200 calls @ 580678us
#
# [14:57:49] EvaluateSplits: 0.016309s, 250 calls @ 16309us
#
# [14:57:49] InitData: 0.122794s, 50 calls @ 122794us
#
# [14:57:49] InitRoot: 14.3572s, 50 calls @ 14357249us
#
# [14:57:49] LeafPartition: 3.8e-05s, 50 calls @ 38us
#
# [14:57:49] UpdatePosition: 1.67879s, 250 calls @ 1678787us
#
# [14:57:49] UpdatePredictionCache: 0.157492s, 50 calls @ 157492us
#
# [14:57:49] UpdateTree: 16.7563s, 50 calls @ 16756311us
#
# [14:57:49] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0;, score=-62.911 total time=  23.6s
# [14:57:56] ======== Monitor (0): HostSketchContainer ========
# [14:57:56] AllReduce: 0.015766s, 1 calls @ 15766us
#
# [14:57:56] MakeCuts: 0.015863s, 1 calls @ 15863us
#
# [14:57:56] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [14:58:12] ======== Monitor (0): Learner ========
# [14:58:12] Configure: 0.000961s, 1 calls @ 961us
#
# [14:58:12] EvalOneIter: 0.001062s, 50 calls @ 1062us
#
# [14:58:12] GetGradient: 0.08813s, 50 calls @ 88130us
#
# [14:58:12] PredictRaw: 0.001279s, 50 calls @ 1279us
#
# [14:58:12] UpdateOneIter: 15.9747s, 50 calls @ 15974719us
#
# [14:58:12] ======== Monitor (0): GBTree ========
# [14:58:12] BoostNewTrees: 15.861s, 50 calls @ 15860959us
#
# [14:58:12] CommitModel: 0.0001s, 50 calls @ 100us
#
# [14:58:12] ======== Monitor (0): HistUpdater ========
# [14:58:12] BuildHistogram: 0.218525s, 200 calls @ 218525us
#
# [14:58:12] EvaluateSplits: 0.014806s, 250 calls @ 14806us
#
# [14:58:12] InitData: 0.103771s, 50 calls @ 103771us
#
# [14:58:12] InitRoot: 13.8907s, 50 calls @ 13890665us
#
# [14:58:12] LeafPartition: 4e-05s, 50 calls @ 40us
#
# [14:58:12] UpdatePosition: 1.48015s, 250 calls @ 1480154us
#
# [14:58:12] UpdatePredictionCache: 0.151016s, 50 calls @ 151016us
#
# [14:58:12] UpdateTree: 15.7084s, 50 calls @ 15708412us
#
# [14:58:12] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0;, score=-64.552 total time=  22.7s
# [14:58:20] ======== Monitor (0): HostSketchContainer ========
# [14:58:20] AllReduce: 0.019181s, 1 calls @ 19181us
#
# [14:58:20] MakeCuts: 0.019287s, 1 calls @ 19287us
#
# [14:58:20] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [14:58:56] ======== Monitor (0): Learner ========
# [14:58:56] Configure: 0.001s, 1 calls @ 1000us
#
# [14:58:56] EvalOneIter: 0.002233s, 100 calls @ 2233us
#
# [14:58:56] GetGradient: 0.160272s, 100 calls @ 160272us
#
# [14:58:56] PredictRaw: 0.001245s, 100 calls @ 1245us
#
# [14:58:56] UpdateOneIter: 35.6964s, 100 calls @ 35696429us
#
# [14:58:56] ======== Monitor (0): GBTree ========
# [14:58:56] BoostNewTrees: 35.503s, 100 calls @ 35502956us
#
# [14:58:56] CommitModel: 0.000175s, 100 calls @ 175us
#
# [14:58:56] ======== Monitor (0): HistUpdater ========
# [14:58:56] BuildHistogram: 2.74606s, 400 calls @ 2746057us
#
# [14:58:56] EvaluateSplits: 0.040802s, 500 calls @ 40802us
#
# [14:58:56] InitData: 0.204237s, 100 calls @ 204237us
#
# [14:58:56] InitRoot: 27.7077s, 100 calls @ 27707692us
#
# [14:58:56] LeafPartition: 7.3e-05s, 100 calls @ 73us
#
# [14:58:56] UpdatePosition: 3.33381s, 500 calls @ 3333808us
#
# [14:58:56] UpdatePredictionCache: 0.344104s, 100 calls @ 344104us
#
# [14:58:56] UpdateTree: 34.0348s, 100 calls @ 34034837us
#
# [14:58:56] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8;, score=-57.241 total time=  44.7s
# [14:59:03] ======== Monitor (0): HostSketchContainer ========
# [14:59:03] AllReduce: 0.015731s, 1 calls @ 15731us
#
# [14:59:03] MakeCuts: 0.015823s, 1 calls @ 15823us
#
# [14:59:03] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [14:59:37] ======== Monitor (0): Learner ========
# [14:59:37] Configure: 0.000875s, 1 calls @ 875us
#
# [14:59:37] EvalOneIter: 0.002218s, 100 calls @ 2218us
#
# [14:59:37] GetGradient: 0.157978s, 100 calls @ 157978us
#
# [14:59:37] PredictRaw: 0.00149s, 100 calls @ 1490us
#
# [14:59:37] UpdateOneIter: 33.3401s, 100 calls @ 33340079us
#
# [14:59:37] ======== Monitor (0): GBTree ========
# [14:59:37] BoostNewTrees: 33.1578s, 100 calls @ 33157803us
#
# [14:59:37] CommitModel: 0.000183s, 100 calls @ 183us
#
# [14:59:37] ======== Monitor (0): HistUpdater ========
# [14:59:37] BuildHistogram: 0.977719s, 400 calls @ 977719us
#
# [14:59:37] EvaluateSplits: 0.032991s, 500 calls @ 32991us
#
# [14:59:37] InitData: 0.188069s, 100 calls @ 188069us
#
# [14:59:37] InitRoot: 28.4337s, 100 calls @ 28433683us
#
# [14:59:37] LeafPartition: 7.9e-05s, 100 calls @ 79us
#
# [14:59:37] UpdatePosition: 3.20294s, 500 calls @ 3202938us
#
# [14:59:37] UpdatePredictionCache: 0.317881s, 100 calls @ 317881us
#
# [14:59:37] UpdateTree: 32.8367s, 100 calls @ 32836702us
#
# [14:59:37] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0;, score=-58.735 total time=  40.8s
# [14:59:46] ======== Monitor (0): HostSketchContainer ========
# [14:59:46] AllReduce: 0.018519s, 1 calls @ 18519us
#
# [14:59:46] MakeCuts: 0.018628s, 1 calls @ 18628us
#
# [14:59:46] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [15:00:56] ======== Monitor (0): Learner ========
# [15:00:56] Configure: 0.001017s, 1 calls @ 1017us
#
# [15:00:56] EvalOneIter: 0.004457s, 200 calls @ 4457us
#
# [15:00:56] GetGradient: 0.323911s, 200 calls @ 323911us
#
# [15:00:56] PredictRaw: 0.001414s, 200 calls @ 1414us
#
# [15:00:56] UpdateOneIter: 70.5188s, 200 calls @ 70518826us
#
# [15:00:56] ======== Monitor (0): GBTree ========
# [15:00:56] BoostNewTrees: 70.161s, 200 calls @ 70161011us
#
# [15:00:56] CommitModel: 0.000348s, 200 calls @ 348us
#
# [15:00:56] ======== Monitor (0): HistUpdater ========
# [15:00:56] BuildHistogram: 3.52763s, 800 calls @ 3527629us
#
# [15:00:56] EvaluateSplits: 0.076622s, 1000 calls @ 76622us
#
# [15:00:56] InitData: 0.425163s, 200 calls @ 425163us
#
# [14:57:05] ======== Monitor (0): HostSketchContainer ========
# [14:57:05] AllReduce: 0.01685s, 1 calls @ 16850us
#
# [14:57:05] MakeCuts: 0.016949s, 1 calls @ 16949us
#
# [14:57:05] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [14:57:25] ======== Monitor (0): Learner ========
# [14:57:25] Configure: 0.001019s, 1 calls @ 1019us
#
# [14:57:25] EvalOneIter: 0.001238s, 50 calls @ 1238us
#
# [14:57:25] GetGradient: 0.104857s, 50 calls @ 104857us
#
# [14:57:25] PredictRaw: 0.001227s, 50 calls @ 1227us
#
# [14:57:25] UpdateOneIter: 20.0447s, 50 calls @ 20044731us
#
# [14:57:25] ======== Monitor (0): GBTree ========
# [14:57:25] BoostNewTrees: 19.9026s, 50 calls @ 19902572us
#
# [14:57:25] CommitModel: 0.000165s, 50 calls @ 165us
#
# [14:57:25] ======== Monitor (0): HistUpdater ========
# [14:57:25] BuildHistogram: 1.49097s, 200 calls @ 1490968us
#
# [14:57:25] EvaluateSplits: 0.021282s, 250 calls @ 21282us
#
# [14:57:25] InitData: 0.131729s, 50 calls @ 131729us
#
# [14:57:25] InitRoot: 15.4605s, 50 calls @ 15460516us
#
# [14:57:25] LeafPartition: 4.4e-05s, 50 calls @ 44us
#
# [14:57:25] UpdatePosition: 2.00814s, 250 calls @ 2008140us
#
# [14:57:25] UpdatePredictionCache: 0.184575s, 50 calls @ 184575us
#
# [14:57:25] UpdateTree: 19.1143s, 50 calls @ 19114342us
#
# [14:57:25] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8;, score=-62.609 total time=  27.0s
# [14:57:32] ======== Monitor (0): HostSketchContainer ========
# [14:57:32] AllReduce: 0.015923s, 1 calls @ 15923us
#
# [14:57:32] MakeCuts: 0.016024s, 1 calls @ 16024us
#
# [14:57:32] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [14:57:49] ======== Monitor (0): Learner ========
# [14:57:49] Configure: 0.000854s, 1 calls @ 854us
#
# [14:57:49] EvalOneIter: 0.000936s, 50 calls @ 936us
#
# [14:57:49] GetGradient: 0.079631s, 50 calls @ 79631us
#
# [14:57:49] PredictRaw: 0.001189s, 50 calls @ 1189us
#
# [14:57:49] UpdateOneIter: 17.0664s, 50 calls @ 17066413us
#
# [14:57:49] ======== Monitor (0): GBTree ========
# [14:57:49] BoostNewTrees: 16.9633s, 50 calls @ 16963323us
#
# [14:57:49] CommitModel: 9.7e-05s, 50 calls @ 97us
#
# [14:57:49] ======== Monitor (0): HistUpdater ========
# [14:57:49] BuildHistogram: 0.467497s, 200 calls @ 467497us
#
# [14:57:49] EvaluateSplits: 0.01588s, 250 calls @ 15880us
#
# [14:57:49] InitData: 0.127679s, 50 calls @ 127679us
#
# [14:57:49] InitRoot: 14.0382s, 50 calls @ 14038173us
#
# [14:57:49] LeafPartition: 3.5e-05s, 50 calls @ 35us
#
# [14:57:49] UpdatePosition: 1.57648s, 250 calls @ 1576484us
#
# [14:57:49] UpdatePredictionCache: 0.155462s, 50 calls @ 155462us
#
# [14:57:49] UpdateTree: 16.2263s, 50 calls @ 16226273us
#
# [14:57:49] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8;, score=-63.768 total time=  23.9s
# [14:57:56] ======== Monitor (0): HostSketchContainer ========
# [14:57:56] AllReduce: 0.016122s, 1 calls @ 16122us
#
# [14:57:56] MakeCuts: 0.016212s, 1 calls @ 16212us
#
# [14:57:56] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [14:58:12] ======== Monitor (0): Learner ========
# [14:58:12] Configure: 0.000906s, 1 calls @ 906us
#
# [14:58:12] EvalOneIter: 0.000953s, 50 calls @ 953us
#
# [14:58:12] GetGradient: 0.08609s, 50 calls @ 86090us
#
# [14:58:12] PredictRaw: 0.001382s, 50 calls @ 1382us
#
# [14:58:12] UpdateOneIter: 16.6742s, 50 calls @ 16674241us
#
# [14:58:12] ======== Monitor (0): GBTree ========
# [14:58:12] BoostNewTrees: 16.5641s, 50 calls @ 16564115us
#
# [14:58:12] CommitModel: 9.3e-05s, 50 calls @ 93us
#
# [14:58:12] ======== Monitor (0): HistUpdater ========
# [14:58:12] BuildHistogram: 0.538467s, 200 calls @ 538467us
#
# [14:58:12] EvaluateSplits: 0.016459s, 250 calls @ 16459us
#
# [14:58:12] InitData: 0.131609s, 50 calls @ 131609us
#
# [14:58:12] InitRoot: 14.0209s, 50 calls @ 14020884us
#
# [14:58:12] LeafPartition: 3.9e-05s, 50 calls @ 39us
#
# [14:58:12] UpdatePosition: 1.68532s, 250 calls @ 1685324us
#
# [14:58:12] UpdatePredictionCache: 0.168967s, 50 calls @ 168967us
#
# [14:58:12] UpdateTree: 16.3935s, 50 calls @ 16393543us
#
# [14:58:12] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0;, score=-62.786 total time=  23.4s
# [14:58:21] ======== Monitor (0): HostSketchContainer ========
# [14:58:21] AllReduce: 0.018643s, 1 calls @ 18643us
#
# [14:58:21] MakeCuts: 0.018746s, 1 calls @ 18746us
#
# [14:58:21] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [14:58:57] ======== Monitor (0): Learner ========
# [14:58:57] Configure: 0.001003s, 1 calls @ 1003us
#
# [14:58:57] EvalOneIter: 0.001904s, 100 calls @ 1904us
#
# [14:58:57] GetGradient: 0.152422s, 100 calls @ 152422us
#
# [14:58:57] PredictRaw: 0.001415s, 100 calls @ 1415us
#
# [14:58:57] UpdateOneIter: 36.0266s, 100 calls @ 36026640us
#
# [14:58:57] ======== Monitor (0): GBTree ========
# [14:58:57] BoostNewTrees: 35.8405s, 100 calls @ 35840482us
#
# [14:58:57] CommitModel: 0.000185s, 100 calls @ 185us
#
# [14:58:57] ======== Monitor (0): HistUpdater ========
# [14:58:57] BuildHistogram: 2.80917s, 400 calls @ 2809166us
#
# [14:58:57] EvaluateSplits: 0.038496s, 500 calls @ 38496us
#
# [14:58:57] InitData: 0.260903s, 100 calls @ 260903us
#
# [14:58:57] InitRoot: 27.8501s, 100 calls @ 27850110us
#
# [14:58:57] LeafPartition: 7.4e-05s, 100 calls @ 74us
#
# [14:58:57] UpdatePosition: 3.46361s, 500 calls @ 3463606us
#
# [14:58:57] UpdatePredictionCache: 0.320646s, 100 calls @ 320646us
#
# [14:58:57] UpdateTree: 34.4245s, 100 calls @ 34424511us
#
# [14:58:57] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8;, score=-57.377 total time=  44.6s
# [14:59:04] ======== Monitor (0): HostSketchContainer ========
# [14:59:04] AllReduce: 0.01618s, 1 calls @ 16180us
#
# [14:59:04] MakeCuts: 0.016274s, 1 calls @ 16274us
#
# [14:59:04] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [14:59:37] ======== Monitor (0): Learner ========
# [14:59:37] Configure: 0.000994s, 1 calls @ 994us
#
# [14:59:37] EvalOneIter: 0.001963s, 100 calls @ 1963us
#
# [14:59:37] GetGradient: 0.155439s, 100 calls @ 155439us
#
# [14:59:37] PredictRaw: 0.001395s, 100 calls @ 1395us
#
# [14:59:37] UpdateOneIter: 33.2388s, 100 calls @ 33238825us
#
# [14:59:37] ======== Monitor (0): GBTree ========
# [14:59:37] BoostNewTrees: 33.0504s, 100 calls @ 33050369us
#
# [14:59:37] CommitModel: 0.000166s, 100 calls @ 166us
#
# [14:59:37] ======== Monitor (0): HistUpdater ========
# [14:59:37] BuildHistogram: 0.920993s, 400 calls @ 920993us
#
# [14:59:37] EvaluateSplits: 0.032694s, 500 calls @ 32694us
#
# [14:59:37] InitData: 0.237601s, 100 calls @ 237601us
#
# [14:59:37] InitRoot: 28.2665s, 100 calls @ 28266517us
#
# [14:59:37] LeafPartition: 8.3e-05s, 100 calls @ 83us
#
# [14:59:37] UpdatePosition: 3.26989s, 500 calls @ 3269895us
#
# [14:59:37] UpdatePredictionCache: 0.318988s, 100 calls @ 318988us
#
# [14:59:37] UpdateTree: 32.7283s, 100 calls @ 32728294us
#
# [14:59:37] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0;, score=-58.429 total time=  40.8s
# [14:59:46] ======== Monitor (0): HostSketchContainer ========
# [14:59:46] AllReduce: 0.018846s, 1 calls @ 18846us
#
# [14:59:46] MakeCuts: 0.018962s, 1 calls @ 18962us
#
# [14:59:46] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [15:00:57] ======== Monitor (0): Learner ========
# [15:00:57] Configure: 0.00096s, 1 calls @ 960us
#
# [15:00:57] EvalOneIter: 0.003833s, 200 calls @ 3833us
#
# [15:00:57] GetGradient: 0.308232s, 200 calls @ 308232us
#
# [15:00:57] PredictRaw: 0.001598s, 200 calls @ 1598us
#
# [15:00:57] UpdateOneIter: 70.4712s, 200 calls @ 70471169us
#
# [15:00:57] ======== Monitor (0): GBTree ========
# [15:00:57] BoostNewTrees: 70.1279s, 200 calls @ 70127922us
#
# [15:00:57] CommitModel: 0.000374s, 200 calls @ 374us
#
# [15:00:57] ======== Monitor (0): HistUpdater ========
# [15:00:57] BuildHistogram: 3.64649s, 800 calls @ 3646485us
#
# [15:00:57] EvaluateSplits: 0.076064s, 1000 calls @ 76064us
#
# [15:00:57] InitData: 0.534903s, 200 calls @ 534903us
#
# [14:57:05] ======== Monitor (0): HostSketchContainer ========
# [14:57:05] AllReduce: 0.016387s, 1 calls @ 16387us
#
# [14:57:05] MakeCuts: 0.016469s, 1 calls @ 16469us
#
# [14:57:05] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [14:57:25] ======== Monitor (0): Learner ========
# [14:57:25] Configure: 0.000916s, 1 calls @ 916us
#
# [14:57:25] EvalOneIter: 0.001246s, 50 calls @ 1246us
#
# [14:57:25] GetGradient: 0.093046s, 50 calls @ 93046us
#
# [14:57:25] PredictRaw: 0.00135s, 50 calls @ 1350us
#
# [14:57:25] UpdateOneIter: 20.3192s, 50 calls @ 20319203us
#
# [14:57:25] ======== Monitor (0): GBTree ========
# [14:57:25] BoostNewTrees: 20.1898s, 50 calls @ 20189807us
#
# [14:57:25] CommitModel: 0.000134s, 50 calls @ 134us
#
# [14:57:25] ======== Monitor (0): HistUpdater ========
# [14:57:25] BuildHistogram: 1.18423s, 200 calls @ 1184228us
#
# [14:57:25] EvaluateSplits: 0.020546s, 250 calls @ 20546us
#
# [14:57:25] InitData: 0.142978s, 50 calls @ 142978us
#
# [14:57:25] InitRoot: 15.9283s, 50 calls @ 15928260us
#
# [14:57:25] LeafPartition: 3.1e-05s, 50 calls @ 31us
#
# [14:57:25] UpdatePosition: 2.09335s, 250 calls @ 2093352us
#
# [14:57:25] UpdatePredictionCache: 0.199047s, 50 calls @ 199047us
#
# [14:57:25] UpdateTree: 19.3706s, 50 calls @ 19370554us
#
# [14:57:25] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8;, score=-62.683 total time=  27.2s
# [14:57:32] ======== Monitor (0): HostSketchContainer ========
# [14:57:32] AllReduce: 0.015887s, 1 calls @ 15887us
#
# [14:57:32] MakeCuts: 0.015985s, 1 calls @ 15985us
#
# [14:57:32] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [14:57:49] ======== Monitor (0): Learner ========
# [14:57:49] Configure: 0.000937s, 1 calls @ 937us
#
# [14:57:49] EvalOneIter: 0.001089s, 50 calls @ 1089us
#
# [14:57:49] GetGradient: 0.094148s, 50 calls @ 94148us
#
# [14:57:49] PredictRaw: 0.001315s, 50 calls @ 1315us
#
# [14:57:49] UpdateOneIter: 17.3276s, 50 calls @ 17327583us
#
# [14:57:49] ======== Monitor (0): GBTree ========
# [14:57:49] BoostNewTrees: 17.1969s, 50 calls @ 17196942us
#
# [14:57:49] CommitModel: 0.00011s, 50 calls @ 110us
#
# [14:57:49] ======== Monitor (0): HistUpdater ========
# [14:57:49] BuildHistogram: 0.619112s, 200 calls @ 619112us
#
# [14:57:49] EvaluateSplits: 0.016682s, 250 calls @ 16682us
#
# [14:57:49] InitData: 0.122289s, 50 calls @ 122289us
#
# [14:57:49] InitRoot: 14.4554s, 50 calls @ 14455379us
#
# [14:57:49] LeafPartition: 4.2e-05s, 50 calls @ 42us
#
# [14:57:49] UpdatePosition: 1.81115s, 250 calls @ 1811145us
#
# [14:57:49] UpdatePredictionCache: 0.169989s, 50 calls @ 169989us
#
# [14:57:49] UpdateTree: 17.0253s, 50 calls @ 17025325us
#
# [14:57:49] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0;, score=-63.110 total time=  23.9s
# [14:57:56] ======== Monitor (0): HostSketchContainer ========
# [14:57:56] AllReduce: 0.016561s, 1 calls @ 16561us
#
# [14:57:56] MakeCuts: 0.016657s, 1 calls @ 16657us
#
# [14:57:56] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [14:58:31] ======== Monitor (0): Learner ========
# [14:58:31] Configure: 0.00093s, 1 calls @ 930us
#
# [14:58:31] EvalOneIter: 0.002237s, 100 calls @ 2237us
#
# [14:58:31] GetGradient: 0.165643s, 100 calls @ 165643us
#
# [14:58:31] PredictRaw: 0.001211s, 100 calls @ 1211us
#
# [14:58:31] UpdateOneIter: 35.2204s, 100 calls @ 35220397us
#
# [14:58:31] ======== Monitor (0): GBTree ========
# [14:58:31] BoostNewTrees: 35.0274s, 100 calls @ 35027422us
#
# [14:58:31] CommitModel: 0.000198s, 100 calls @ 198us
#
# [14:58:31] ======== Monitor (0): HistUpdater ========
# [14:58:31] BuildHistogram: 2.26123s, 400 calls @ 2261225us
#
# [14:58:31] EvaluateSplits: 0.037533s, 500 calls @ 37533us
#
# [14:58:31] InitData: 0.237987s, 100 calls @ 237987us
#
# [14:58:31] InitRoot: 27.6231s, 100 calls @ 27623121us
#
# [14:58:31] LeafPartition: 5.1e-05s, 100 calls @ 51us
#
# [14:58:31] UpdatePosition: 3.41528s, 500 calls @ 3415278us
#
# [14:58:31] UpdatePredictionCache: 0.327374s, 100 calls @ 327374us
#
# [14:58:31] UpdateTree: 33.5769s, 100 calls @ 33576927us
#
# [14:58:31] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8;, score=-57.754 total time=  42.7s
# [14:58:40] ======== Monitor (0): HostSketchContainer ========
# [14:58:40] AllReduce: 0.018308s, 1 calls @ 18308us
#
# [14:58:40] MakeCuts: 0.01842s, 1 calls @ 18420us
#
# [14:58:40] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [14:59:15] ======== Monitor (0): Learner ========
# [14:59:15] Configure: 0.000964s, 1 calls @ 964us
#
# [14:59:15] EvalOneIter: 0.002208s, 100 calls @ 2208us
#
# [14:59:15] GetGradient: 0.16214s, 100 calls @ 162140us
#
# [14:59:15] PredictRaw: 0.001483s, 100 calls @ 1483us
#
# [14:59:15] UpdateOneIter: 34.9033s, 100 calls @ 34903263us
#
# [14:59:15] ======== Monitor (0): GBTree ========
# [14:59:15] BoostNewTrees: 34.7078s, 100 calls @ 34707787us
#
# [14:59:15] CommitModel: 0.000189s, 100 calls @ 189us
#
# [14:59:15] ======== Monitor (0): HistUpdater ========
# [14:59:15] BuildHistogram: 1.30118s, 400 calls @ 1301184us
#
# [14:59:15] EvaluateSplits: 0.032986s, 500 calls @ 32986us
#
# [14:59:15] InitData: 0.23099s, 100 calls @ 230990us
#
# [14:59:15] InitRoot: 28.3633s, 100 calls @ 28363251us
#
# [14:59:15] LeafPartition: 8e-05s, 100 calls @ 80us
#
# [14:59:15] UpdatePosition: 3.25981s, 500 calls @ 3259808us
#
# [14:59:15] UpdatePredictionCache: 0.312792s, 100 calls @ 312792us
#
# [14:59:15] UpdateTree: 33.1896s, 100 calls @ 33189646us
#
# [14:59:15] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8;, score=-59.520 total time=  43.4s
# [14:59:22] ======== Monitor (0): HostSketchContainer ========
# [14:59:22] AllReduce: 0.01595s, 1 calls @ 15950us
#
# [14:59:22] MakeCuts: 0.016045s, 1 calls @ 16045us
#
# [14:59:22] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [14:59:55] ======== Monitor (0): Learner ========
# [14:59:55] Configure: 0.000868s, 1 calls @ 868us
#
# [14:59:55] EvalOneIter: 0.002248s, 100 calls @ 2248us
#
# [14:59:55] GetGradient: 0.163597s, 100 calls @ 163597us
#
# [14:59:55] PredictRaw: 0.001454s, 100 calls @ 1454us
#
# [14:59:55] UpdateOneIter: 32.952s, 100 calls @ 32951967us
#
# [14:59:55] ======== Monitor (0): GBTree ========
# [14:59:55] BoostNewTrees: 32.7561s, 100 calls @ 32756134us
#
# [14:59:55] CommitModel: 0.000195s, 100 calls @ 195us
#
# [14:59:55] ======== Monitor (0): HistUpdater ========
# [14:59:55] BuildHistogram: 0.980139s, 400 calls @ 980139us
#
# [14:59:55] EvaluateSplits: 0.034685s, 500 calls @ 34685us
#
# [14:59:55] InitData: 0.218019s, 100 calls @ 218019us
#
# [14:59:55] InitRoot: 28.03s, 100 calls @ 28029973us
#
# [14:59:55] LeafPartition: 7.4e-05s, 100 calls @ 74us
#
# [14:59:55] UpdatePosition: 3.1888s, 500 calls @ 3188805us
#
# [14:59:55] UpdatePredictionCache: 0.302563s, 100 calls @ 302563us
#
# [14:59:55] UpdateTree: 32.4504s, 100 calls @ 32450370us
#
# [14:59:55] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0;, score=-58.526 total time=  40.1s
# [15:00:04] ======== Monitor (0): HostSketchContainer ========
# [15:00:04] AllReduce: 0.017531s, 1 calls @ 17531us
#
# [15:00:04] MakeCuts: 0.017641s, 1 calls @ 17641us
#
# [15:00:04] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [15:01:14] ======== Monitor (0): Learner ========
# [15:01:14] Configure: 0.000954s, 1 calls @ 954us
#
# [15:01:14] EvalOneIter: 0.004372s, 200 calls @ 4372us
#
# [15:01:14] GetGradient: 0.33192s, 200 calls @ 331920us
#
# [15:01:14] PredictRaw: 0.001608s, 200 calls @ 1608us
#
# [15:01:14] UpdateOneIter: 70.2098s, 200 calls @ 70209824us
#
# [15:01:14] ======== Monitor (0): GBTree ========
# [15:01:14] BoostNewTrees: 69.8435s, 200 calls @ 69843506us
#
# [15:01:14] CommitModel: 0.000358s, 200 calls @ 358us
#
# [15:01:14] ======== Monitor (0): HistUpdater ========
# [15:01:14] BuildHistogram: 3.88653s, 800 calls @ 3886531us
#
# [15:01:14] EvaluateSplits: 0.07906s, 1000 calls @ 79060us
#
# [15:01:14] InitData: 0.473045s, 200 calls @ 473045us
#
# [14:57:05] ======== Monitor (0): HostSketchContainer ========
# [14:57:05] AllReduce: 0.019262s, 1 calls @ 19262us
#
# [14:57:05] MakeCuts: 0.019354s, 1 calls @ 19354us
#
# [14:57:05] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [14:57:26] ======== Monitor (0): Learner ========
# [14:57:26] Configure: 0.000958s, 1 calls @ 958us
#
# [14:57:26] EvalOneIter: 0.001209s, 50 calls @ 1209us
#
# [14:57:26] GetGradient: 0.105972s, 50 calls @ 105972us
#
# [14:57:26] PredictRaw: 0.00133s, 50 calls @ 1330us
#
# [14:57:26] UpdateOneIter: 21.0428s, 50 calls @ 21042842us
#
# [14:57:26] ======== Monitor (0): GBTree ========
# [14:57:26] BoostNewTrees: 20.8995s, 50 calls @ 20899525us
#
# [14:57:26] CommitModel: 0.000149s, 50 calls @ 149us
#
# [14:57:26] ======== Monitor (0): HistUpdater ========
# [14:57:26] BuildHistogram: 1.26961s, 200 calls @ 1269612us
#
# [14:57:26] EvaluateSplits: 0.021355s, 250 calls @ 21355us
#
# [14:57:26] InitData: 0.149272s, 50 calls @ 149272us
#
# [14:57:26] InitRoot: 16.3789s, 50 calls @ 16378948us
#
# [14:57:26] LeafPartition: 4e-05s, 50 calls @ 40us
#
# [14:57:26] UpdatePosition: 2.1891s, 250 calls @ 2189100us
#
# [14:57:26] UpdatePredictionCache: 0.210904s, 50 calls @ 210904us
#
# [14:57:26] UpdateTree: 20.0097s, 50 calls @ 20009671us
#
# [14:57:26] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=0.8;, score=-62.916 total time=  27.9s
# [14:57:33] ======== Monitor (0): HostSketchContainer ========
# [14:57:33] AllReduce: 0.016092s, 1 calls @ 16092us
#
# [14:57:33] MakeCuts: 0.016183s, 1 calls @ 16183us
#
# [14:57:33] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [14:57:50] ======== Monitor (0): Learner ========
# [14:57:50] Configure: 0.001005s, 1 calls @ 1005us
#
# [14:57:50] EvalOneIter: 0.000971s, 50 calls @ 971us
#
# [14:57:50] GetGradient: 0.088298s, 50 calls @ 88298us
#
# [14:57:50] PredictRaw: 0.001403s, 50 calls @ 1403us
#
# [14:57:50] UpdateOneIter: 17.1484s, 50 calls @ 17148357us
#
# [14:57:50] ======== Monitor (0): GBTree ========
# [14:57:50] BoostNewTrees: 17.0241s, 50 calls @ 17024073us
#
# [14:57:50] CommitModel: 9.3e-05s, 50 calls @ 93us
#
# [14:57:50] ======== Monitor (0): HistUpdater ========
# [14:57:50] BuildHistogram: 0.54273s, 200 calls @ 542730us
#
# [14:57:50] EvaluateSplits: 0.016947s, 250 calls @ 16947us
#
# [14:57:50] InitData: 0.116155s, 50 calls @ 116155us
#
# [14:57:50] InitRoot: 14.4623s, 50 calls @ 14462304us
#
# [14:57:50] LeafPartition: 3.3e-05s, 50 calls @ 33us
#
# [14:57:50] UpdatePosition: 1.70513s, 250 calls @ 1705133us
#
# [14:57:50] UpdatePredictionCache: 0.178144s, 50 calls @ 178144us
#
# [14:57:50] UpdateTree: 16.8444s, 50 calls @ 16844370us
#
# [14:57:50] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=50, subsample=1.0;, score=-62.718 total time=  23.9s
# [14:57:57] ======== Monitor (0): HostSketchContainer ========
# [14:57:57] AllReduce: 0.016153s, 1 calls @ 16153us
#
# [14:57:57] MakeCuts: 0.016267s, 1 calls @ 16267us
#
# [14:57:57] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [14:58:33] ======== Monitor (0): Learner ========
# [14:58:33] Configure: 0.000985s, 1 calls @ 985us
#
# [14:58:33] EvalOneIter: 0.001918s, 100 calls @ 1918us
#
# [14:58:33] GetGradient: 0.172419s, 100 calls @ 172419us
#
# [14:58:33] PredictRaw: 0.001636s, 100 calls @ 1636us
#
# [14:58:33] UpdateOneIter: 36.0077s, 100 calls @ 36007703us
#
# [14:58:33] ======== Monitor (0): GBTree ========
# [14:58:33] BoostNewTrees: 35.8007s, 100 calls @ 35800674us
#
# [14:58:33] CommitModel: 0.000178s, 100 calls @ 178us
#
# [14:58:33] ======== Monitor (0): HistUpdater ========
# [14:58:33] BuildHistogram: 2.43204s, 400 calls @ 2432039us
#
# [14:58:33] EvaluateSplits: 0.038817s, 500 calls @ 38817us
#
# [14:58:33] InitData: 0.27608s, 100 calls @ 276080us
#
# [14:58:33] InitRoot: 28.0304s, 100 calls @ 28030405us
#
# [14:58:33] LeafPartition: 7.8e-05s, 100 calls @ 78us
#
# [14:58:33] UpdatePosition: 3.56052s, 500 calls @ 3560515us
#
# [14:58:33] UpdatePredictionCache: 0.334038s, 100 calls @ 334038us
#
# [14:58:33] UpdateTree: 34.34s, 100 calls @ 34340037us
#
# [14:58:33] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=0.8;, score=-57.538 total time=  43.7s
# [14:58:42] ======== Monitor (0): HostSketchContainer ========
# [14:58:42] AllReduce: 0.015858s, 1 calls @ 15858us
#
# [14:58:42] MakeCuts: 0.015954s, 1 calls @ 15954us
#
# [14:58:42] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [14:59:15] ======== Monitor (0): Learner ========
# [14:59:15] Configure: 0.001301s, 1 calls @ 1301us
#
# [14:59:15] EvalOneIter: 0.001936s, 100 calls @ 1936us
#
# [14:59:15] GetGradient: 0.173809s, 100 calls @ 173809us
#
# [14:59:15] PredictRaw: 0.001405s, 100 calls @ 1405us
#
# [14:59:15] UpdateOneIter: 33.4125s, 100 calls @ 33412546us
#
# [14:59:15] ======== Monitor (0): GBTree ========
# [14:59:15] BoostNewTrees: 33.203s, 100 calls @ 33202998us
#
# [14:59:15] CommitModel: 0.000182s, 100 calls @ 182us
#
# [14:59:15] ======== Monitor (0): HistUpdater ========
# [14:59:15] BuildHistogram: 0.978382s, 400 calls @ 978382us
#
# [14:59:15] EvaluateSplits: 0.032958s, 500 calls @ 32958us
#
# [14:59:15] InitData: 0.244987s, 100 calls @ 244987us
#
# [14:59:15] InitRoot: 28.3721s, 100 calls @ 28372113us
#
# [14:59:15] LeafPartition: 7e-05s, 100 calls @ 70us
#
# [14:59:15] UpdatePosition: 3.24572s, 500 calls @ 3245717us
#
# [14:59:15] UpdatePredictionCache: 0.324623s, 100 calls @ 324623us
#
# [14:59:15] UpdateTree: 32.8753s, 100 calls @ 32875264us
#
# [14:59:15] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0;, score=-59.128 total time=  41.8s
# [14:59:22] ======== Monitor (0): HostSketchContainer ========
# [14:59:22] AllReduce: 0.017751s, 1 calls @ 17751us
#
# [14:59:22] MakeCuts: 0.017854s, 1 calls @ 17854us
#
# [14:59:22] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [14:59:54] ======== Monitor (0): Learner ========
# [14:59:54] Configure: 0.000903s, 1 calls @ 903us
#
# [14:59:54] EvalOneIter: 0.002003s, 100 calls @ 2003us
#
# [14:59:54] GetGradient: 0.180555s, 100 calls @ 180555us
#
# [14:59:54] PredictRaw: 0.001266s, 100 calls @ 1266us
#
# [14:59:54] UpdateOneIter: 32.0641s, 100 calls @ 32064054us
#
# [14:59:54] ======== Monitor (0): GBTree ========
# [14:59:54] BoostNewTrees: 31.8588s, 100 calls @ 31858754us
#
# [14:59:54] CommitModel: 0.000203s, 100 calls @ 203us
#
# [14:59:54] ======== Monitor (0): HistUpdater ========
# [14:59:54] BuildHistogram: 0.379538s, 400 calls @ 379538us
#
# [14:59:54] EvaluateSplits: 0.029039s, 500 calls @ 29039us
#
# [14:59:54] InitData: 0.232379s, 100 calls @ 232379us
#
# [14:59:54] InitRoot: 27.9033s, 100 calls @ 27903265us
#
# [14:59:54] LeafPartition: 7.4e-05s, 100 calls @ 74us
#
# [14:59:54] UpdatePosition: 3.02236s, 500 calls @ 3022359us
#
# [14:59:54] UpdatePredictionCache: 0.288165s, 100 calls @ 288165us
#
# [14:59:54] UpdateTree: 31.5675s, 100 calls @ 31567529us
#
# [14:59:54] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=100, subsample=1.0;, score=-60.847 total time=  39.8s
# [15:00:03] ======== Monitor (0): HostSketchContainer ========
# [15:00:03] AllReduce: 0.018668s, 1 calls @ 18668us
#
# [15:00:03] MakeCuts: 0.018776s, 1 calls @ 18776us
#
# [15:00:03] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [15:01:14] ======== Monitor (0): Learner ========
# [15:01:14] Configure: 0.00108s, 1 calls @ 1080us
#
# [15:01:14] EvalOneIter: 0.003893s, 200 calls @ 3893us
#
# [15:01:14] GetGradient: 0.353407s, 200 calls @ 353407us
#
# [15:01:14] PredictRaw: 0.001603s, 200 calls @ 1603us
#
# [15:01:14] UpdateOneIter: 70.7565s, 200 calls @ 70756503us
#
# [15:01:14] ======== Monitor (0): GBTree ========
# [15:01:14] BoostNewTrees: 70.3669s, 200 calls @ 70366887us
#
# [15:01:14] CommitModel: 0.000338s, 200 calls @ 338us
#
# [15:01:14] ======== Monitor (0): HistUpdater ========
# [15:01:14] BuildHistogram: 3.98353s, 800 calls @ 3983534us
#
# [15:01:14] EvaluateSplits: 0.077289s, 1000 calls @ 77289us
#
# [15:01:14] InitData: 0.490192s, 200 calls @ 490192us
# [15:00:56] InitRoot: 56.5772s, 200 calls @ 56577171us
#
# [15:00:56] LeafPartition: 9.1e-05s, 200 calls @ 91us
#
# [15:00:56] UpdatePosition: 6.58965s, 1000 calls @ 6589653us
#
# [15:00:56] UpdatePredictionCache: 0.652509s, 200 calls @ 652509us
#
# [15:00:56] UpdateTree: 67.2013s, 200 calls @ 67201317us
#
# [15:00:56] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8;, score=-50.467 total time= 1.3min
# [15:01:07] ======== Monitor (0): HostSketchContainer ========
# [15:01:07] AllReduce: 0.018877s, 1 calls @ 18877us
#
# [15:01:07] MakeCuts: 0.018995s, 1 calls @ 18995us
#
# [15:01:07] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [15:02:15] ======== Monitor (0): Learner ========
# [15:02:15] Configure: 0.000946s, 1 calls @ 946us
#
# [15:02:15] EvalOneIter: 0.004386s, 200 calls @ 4386us
#
# [15:02:15] GetGradient: 0.33088s, 200 calls @ 330880us
#
# [15:02:15] PredictRaw: 0.001677s, 200 calls @ 1677us
#
# [15:02:15] UpdateOneIter: 68.2607s, 200 calls @ 68260679us
#
# [15:02:15] ======== Monitor (0): GBTree ========
# [15:02:15] BoostNewTrees: 67.8962s, 200 calls @ 67896222us
#
# [15:02:15] CommitModel: 0.000385s, 200 calls @ 385us
#
# [15:02:15] ======== Monitor (0): HistUpdater ========
# [15:02:15] BuildHistogram: 1.91965s, 800 calls @ 1919646us
#
# [15:02:15] EvaluateSplits: 0.067115s, 1000 calls @ 67115us
#
# [15:02:15] InitData: 0.471429s, 200 calls @ 471429us
#
# [15:02:15] InitRoot: 56.3974s, 200 calls @ 56397438us
#
# [15:02:15] LeafPartition: 0.000107s, 200 calls @ 107us
#
# [15:02:15] UpdatePosition: 6.13385s, 1000 calls @ 6133848us
#
# [15:02:15] UpdatePredictionCache: 0.609731s, 200 calls @ 609731us
#
# [15:02:15] UpdateTree: 64.9933s, 200 calls @ 64993307us
#
# [15:02:15] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8;, score=-54.083 total time= 1.3min
# [15:02:25] ======== Monitor (0): HostSketchContainer ========
# [15:02:25] AllReduce: 0.018215s, 1 calls @ 18215us
#
# [15:02:25] MakeCuts: 0.018324s, 1 calls @ 18324us
#
# [15:02:25] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [15:03:29] ======== Monitor (0): Learner ========
# [15:03:29] Configure: 0.00098s, 1 calls @ 980us
#
# [15:03:29] EvalOneIter: 0.004369s, 200 calls @ 4369us
#
# [15:03:29] GetGradient: 0.337999s, 200 calls @ 337999us
#
# [15:03:29] PredictRaw: 0.001619s, 200 calls @ 1619us
#
# [15:03:29] UpdateOneIter: 63.5987s, 200 calls @ 63598718us
#
# [15:03:29] ======== Monitor (0): GBTree ========
# [15:03:29] BoostNewTrees: 63.226s, 200 calls @ 63225957us
#
# [15:03:29] CommitModel: 0.000323s, 200 calls @ 323us
#
# [15:03:29] ======== Monitor (0): HistUpdater ========
# [15:03:29] BuildHistogram: 0.777065s, 800 calls @ 777065us
#
# [15:03:29] EvaluateSplits: 0.059123s, 1000 calls @ 59123us
#
# [15:03:29] InitData: 0.399994s, 200 calls @ 399994us
#
# [15:03:29] InitRoot: 55.5497s, 200 calls @ 55549655us
#
# [15:03:29] LeafPartition: 0.000101s, 200 calls @ 101us
#
# [15:03:29] UpdatePosition: 5.87783s, 1000 calls @ 5877830us
#
# [15:03:29] UpdatePredictionCache: 0.553209s, 200 calls @ 553209us
#
# [15:03:29] UpdateTree: 62.6665s, 200 calls @ 62666546us
#
# [15:03:29] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0;, score=-57.351 total time= 1.2min
# [15:03:39] ======== Monitor (0): HostSketchContainer ========
# [15:03:39] AllReduce: 0.019779s, 1 calls @ 19779us
#
# [15:03:39] MakeCuts: 0.019887s, 1 calls @ 19887us
#
# [15:03:39] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [15:04:17] ======== Monitor (0): Learner ========
# [15:04:17] Configure: 0.001563s, 1 calls @ 1563us
#
# [15:04:17] EvalOneIter: 0.00113s, 50 calls @ 1130us
#
# [15:04:17] GetGradient: 0.071565s, 50 calls @ 71565us
#
# [15:04:17] PredictRaw: 0.001069s, 50 calls @ 1069us
#
# [15:04:17] UpdateOneIter: 38.1736s, 50 calls @ 38173624us
#
# [15:04:17] ======== Monitor (0): GBTree ========
# [15:04:17] BoostNewTrees: 38.0694s, 50 calls @ 38069398us
#
# [15:04:17] CommitModel: 0.000104s, 50 calls @ 104us
#
# [15:04:17] ======== Monitor (0): HistUpdater ========
# [15:04:17] BuildHistogram: 18.976s, 450 calls @ 18976018us
#
# [15:04:17] EvaluateSplits: 0.185953s, 500 calls @ 185953us
#
# [15:04:17] InitData: 0.099676s, 50 calls @ 99676us
#
# [15:04:17] InitRoot: 13.8767s, 50 calls @ 13876722us
#
# [15:04:17] LeafPartition: 2.8e-05s, 50 calls @ 28us
#
# [15:04:17] UpdatePosition: 4.70843s, 500 calls @ 4708435us
#
# [15:04:17] UpdatePredictionCache: 0.208929s, 50 calls @ 208929us
#
# [15:04:17] UpdateTree: 37.8588s, 50 calls @ 37858811us
#
# [15:04:17] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=50, subsample=1.0;, score=-62.824 total time=  47.2s
# [15:04:25] ======== Monitor (0): HostSketchContainer ========
# [15:04:25] AllReduce: 0.016823s, 1 calls @ 16823us
#
# [15:04:25] MakeCuts: 0.016935s, 1 calls @ 16935us
#
# [15:04:25] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [15:05:00] ======== Monitor (0): Learner ========
# [15:05:00] Configure: 0.001016s, 1 calls @ 1016us
#
# [15:05:00] EvalOneIter: 0.001103s, 50 calls @ 1103us
#
# [15:05:00] GetGradient: 0.092798s, 50 calls @ 92798us
#
# [15:05:00] PredictRaw: 0.001161s, 50 calls @ 1161us
#
# [15:05:00] UpdateOneIter: 34.6132s, 50 calls @ 34613201us
#
# [15:05:00] ======== Monitor (0): GBTree ========
# [15:05:00] BoostNewTrees: 34.493s, 50 calls @ 34493032us
#
# [15:05:00] CommitModel: 0.0001s, 50 calls @ 100us
#
# [15:05:00] ======== Monitor (0): HistUpdater ========
# [15:05:00] BuildHistogram: 15.5088s, 450 calls @ 15508807us
#
# [15:05:00] EvaluateSplits: 0.151749s, 500 calls @ 151749us
#
# [15:05:00] InitData: 0.10213s, 50 calls @ 102130us
#
# [15:05:00] InitRoot: 13.9764s, 50 calls @ 13976421us
#
# [15:05:00] LeafPartition: 3.7e-05s, 50 calls @ 37us
#
# [15:05:00] UpdatePosition: 4.55055s, 500 calls @ 4550549us
#
# [15:05:00] UpdatePredictionCache: 0.192002s, 50 calls @ 192002us
#
# [15:05:00] UpdateTree: 34.2994s, 50 calls @ 34299390us
#
# [15:05:00] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=50, subsample=1.0;, score=-62.446 total time=  43.1s
# [15:05:07] ======== Monitor (0): HostSketchContainer ========
# [15:05:07] AllReduce: 0.015976s, 1 calls @ 15976us
#
# [15:05:07] MakeCuts: 0.01608s, 1 calls @ 16080us
#
# [15:05:07] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [15:06:32] ======== Monitor (0): Learner ========
# [15:06:32] Configure: 0.000901s, 1 calls @ 901us
#
# [15:06:32] EvalOneIter: 0.002168s, 100 calls @ 2168us
#
# [15:06:32] GetGradient: 0.160543s, 100 calls @ 160543us
#
# [15:06:32] PredictRaw: 0.001127s, 100 calls @ 1127us
#
# [15:06:32] UpdateOneIter: 84.9363s, 100 calls @ 84936331us
#
# [15:06:32] ======== Monitor (0): GBTree ========
# [15:06:32] BoostNewTrees: 84.752s, 100 calls @ 84751963us
#
# [15:06:32] CommitModel: 0.000186s, 100 calls @ 186us
#
# [15:06:32] ======== Monitor (0): HistUpdater ========
# [15:06:32] BuildHistogram: 44.6455s, 900 calls @ 44645539us
#
# [15:06:32] EvaluateSplits: 0.497092s, 1000 calls @ 497092us
#
# [15:06:32] InitData: 0.212988s, 100 calls @ 212988us
#
# [15:06:32] InitRoot: 27.8796s, 100 calls @ 27879565us
#
# [15:06:32] LeafPartition: 5.2e-05s, 100 calls @ 52us
#
# [15:06:32] UpdatePosition: 9.93289s, 1002 calls @ 9932893us
#
# [15:06:32] UpdatePredictionCache: 0.408459s, 100 calls @ 408459us
#
# [15:06:32] UpdateTree: 83.2s, 100 calls @ 83199958us
#
# [15:06:32] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=100, subsample=0.8;, score=-57.222 total time= 1.6min
# [15:06:41] ======== Monitor (0): HostSketchContainer ========
# [15:06:41] AllReduce: 0.015762s, 1 calls @ 15762us
#
# [15:06:41] MakeCuts: 0.015866s, 1 calls @ 15866us
#
# [15:06:41] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [15:07:59] ======== Monitor (0): Learner ========
# [15:07:59] Configure: 0.00103s, 1 calls @ 1030us
#
# [15:07:59] EvalOneIter: 0.002174s, 100 calls @ 2174us
#
# [15:01:14] InitRoot: 55.7765s, 200 calls @ 55776464us
#
# [15:01:14] LeafPartition: 0.000164s, 200 calls @ 164us
#
# [15:01:14] UpdatePosition: 6.70135s, 1000 calls @ 6701354us
#
# [15:01:14] UpdatePredictionCache: 0.631564s, 200 calls @ 631564us
#
# [15:01:14] UpdateTree: 66.9224s, 200 calls @ 66922433us
#
# [15:01:14] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=0.8;, score=-50.540 total time= 1.3min
# [15:01:24] ======== Monitor (0): HostSketchContainer ========
# [15:01:24] AllReduce: 0.020685s, 1 calls @ 20685us
#
# [15:01:24] MakeCuts: 0.020798s, 1 calls @ 20798us
#
# [15:01:24] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [15:02:30] ======== Monitor (0): Learner ========
# [15:02:30] Configure: 0.000939s, 1 calls @ 939us
#
# [15:02:30] EvalOneIter: 0.004366s, 200 calls @ 4366us
#
# [15:02:30] GetGradient: 0.343437s, 200 calls @ 343437us
#
# [15:02:30] PredictRaw: 0.001413s, 200 calls @ 1413us
#
# [15:02:30] UpdateOneIter: 65.3801s, 200 calls @ 65380128us
#
# [15:02:30] ======== Monitor (0): GBTree ========
# [15:02:30] BoostNewTrees: 65.0027s, 200 calls @ 65002729us
#
# [15:02:30] CommitModel: 0.000371s, 200 calls @ 371us
#
# [15:02:30] ======== Monitor (0): HistUpdater ========
# [15:02:30] BuildHistogram: 1.52796s, 800 calls @ 1527961us
#
# [15:02:30] EvaluateSplits: 0.063804s, 1000 calls @ 63804us
#
# [15:02:30] InitData: 0.45277s, 200 calls @ 452770us
#
# [15:02:30] InitRoot: 56.023s, 200 calls @ 56023008us
#
# [15:02:30] LeafPartition: 0.000123s, 200 calls @ 123us
#
# [15:02:30] UpdatePosition: 6.32937s, 1000 calls @ 6329374us
#
# [15:02:30] UpdatePredictionCache: 0.597822s, 200 calls @ 597822us
#
# [15:02:30] UpdateTree: 64.3989s, 200 calls @ 64398860us
#
# [15:02:30] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=5, n_estimators=200, subsample=1.0;, score=-54.120 total time= 1.3min
# [15:02:40] ======== Monitor (0): HostSketchContainer ========
# [15:02:40] AllReduce: 0.018453s, 1 calls @ 18453us
#
# [15:02:40] MakeCuts: 0.018565s, 1 calls @ 18565us
#
# [15:02:40] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [15:03:23] ======== Monitor (0): Learner ========
# [15:03:23] Configure: 0.000962s, 1 calls @ 962us
#
# [15:03:23] EvalOneIter: 0.001069s, 50 calls @ 1069us
#
# [15:03:23] GetGradient: 0.080213s, 50 calls @ 80213us
#
# [15:03:23] PredictRaw: 0.001177s, 50 calls @ 1177us
#
# [15:03:23] UpdateOneIter: 42.9323s, 50 calls @ 42932294us
#
# [15:03:23] ======== Monitor (0): GBTree ========
# [15:03:23] BoostNewTrees: 42.8198s, 50 calls @ 42819766us
#
# [15:03:23] CommitModel: 0.000105s, 50 calls @ 105us
#
# [15:03:23] ======== Monitor (0): HistUpdater ========
# [15:03:23] BuildHistogram: 22.1909s, 450 calls @ 22190892us
#
# [15:03:23] EvaluateSplits: 0.235264s, 500 calls @ 235264us
#
# [15:03:23] InitData: 0.124054s, 50 calls @ 124054us
#
# [15:03:23] InitRoot: 14.2627s, 50 calls @ 14262741us
#
# [15:03:23] LeafPartition: 3e-05s, 50 calls @ 30us
#
# [15:03:23] UpdatePosition: 5.16488s, 500 calls @ 5164885us
#
# [15:03:23] UpdatePredictionCache: 0.237137s, 50 calls @ 237137us
#
# [15:03:23] UpdateTree: 41.9922s, 50 calls @ 41992217us
#
# [15:03:23] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=50, subsample=0.8;, score=-62.816 total time=  52.5s
# [15:03:32] ======== Monitor (0): HostSketchContainer ========
# [15:03:32] AllReduce: 0.014995s, 1 calls @ 14995us
#
# [15:03:32] MakeCuts: 0.015095s, 1 calls @ 15095us
#
# [15:03:32] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [15:04:15] ======== Monitor (0): Learner ========
# [15:04:15] Configure: 0.000827s, 1 calls @ 827us
#
# [15:04:15] EvalOneIter: 0.001086s, 50 calls @ 1086us
#
# [15:04:15] GetGradient: 0.07416s, 50 calls @ 74160us
#
# [15:04:15] PredictRaw: 0.001133s, 50 calls @ 1133us
#
# [15:04:15] UpdateOneIter: 42.7838s, 50 calls @ 42783789us
#
# [15:04:15] ======== Monitor (0): GBTree ========
# [15:04:15] BoostNewTrees: 42.6854s, 50 calls @ 42685360us
#
# [15:04:15] CommitModel: 0.00011s, 50 calls @ 110us
#
# [15:04:15] ======== Monitor (0): HistUpdater ========
# [15:04:15] BuildHistogram: 22.2749s, 450 calls @ 22274934us
#
# [15:04:15] EvaluateSplits: 0.268411s, 500 calls @ 268411us
#
# [15:04:15] InitData: 0.111635s, 50 calls @ 111635us
#
# [15:04:15] InitRoot: 14.0993s, 50 calls @ 14099338us
#
# [15:04:15] LeafPartition: 2.8e-05s, 50 calls @ 28us
#
# [15:04:15] UpdatePosition: 5.12319s, 501 calls @ 5123195us
#
# [15:04:15] UpdatePredictionCache: 0.219928s, 50 calls @ 219928us
#
# [15:04:15] UpdateTree: 41.893s, 50 calls @ 41892954us
#
# [15:04:15] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=50, subsample=0.8;, score=-62.388 total time=  50.7s
# [15:04:22] ======== Monitor (0): HostSketchContainer ========
# [15:04:22] AllReduce: 0.016218s, 1 calls @ 16218us
#
# [15:04:22] MakeCuts: 0.016326s, 1 calls @ 16326us
#
# [15:04:22] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [15:05:01] ======== Monitor (0): Learner ========
# [15:05:01] Configure: 0.000979s, 1 calls @ 979us
#
# [15:05:01] EvalOneIter: 0.001071s, 50 calls @ 1071us
#
# [15:05:01] GetGradient: 0.078826s, 50 calls @ 78826us
#
# [15:05:01] PredictRaw: 0.001102s, 50 calls @ 1102us
#
# [15:05:01] UpdateOneIter: 39.3748s, 50 calls @ 39374812us
#
# [15:05:01] ======== Monitor (0): GBTree ========
# [15:05:01] BoostNewTrees: 39.2694s, 50 calls @ 39269428us
#
# [15:05:01] CommitModel: 0.000107s, 50 calls @ 107us
#
# [15:05:01] ======== Monitor (0): HistUpdater ========
# [15:05:01] BuildHistogram: 19.5903s, 450 calls @ 19590279us
#
# [15:05:01] EvaluateSplits: 0.193283s, 500 calls @ 193283us
#
# [15:05:01] InitData: 0.116964s, 50 calls @ 116964us
#
# [15:05:01] InitRoot: 14.1848s, 50 calls @ 14184760us
#
# [15:05:01] LeafPartition: 2.8e-05s, 50 calls @ 28us
#
# [15:05:01] UpdatePosition: 4.95726s, 500 calls @ 4957259us
#
# [15:05:01] UpdatePredictionCache: 0.21239s, 50 calls @ 212390us
#
# [15:05:01] UpdateTree: 39.0553s, 50 calls @ 39055336us
#
# [15:05:01] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=10, n_estimators=50, subsample=1.0;, score=-62.357 total time=  46.8s
# [15:05:09] ======== Monitor (0): HostSketchContainer ========
# [15:05:09] AllReduce: 0.016167s, 1 calls @ 16167us
#
# [15:05:09] MakeCuts: 0.016267s, 1 calls @ 16267us
#
# [15:05:09] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [15:06:34] ======== Monitor (0): Learner ========
# [15:06:34] Configure: 0.001048s, 1 calls @ 1048us
#
# [15:06:34] EvalOneIter: 0.002105s, 100 calls @ 2105us
#
# [15:06:34] GetGradient: 0.170067s, 100 calls @ 170067us
#
# [15:06:34] PredictRaw: 0.002478s, 100 calls @ 2478us
#
# [15:06:34] UpdateOneIter: 85.3647s, 100 calls @ 85364682us
#
# [15:06:34] ======== Monitor (0): GBTree ========
# [15:06:34] BoostNewTrees: 85.1658s, 100 calls @ 85165831us
#
# [15:06:34] CommitModel: 0.000243s, 100 calls @ 243us
#
# ...
# [19:08:00] ======== Monitor (0): HostSketchContainer ========
# [19:08:00] AllReduce: 0.014518s, 1 calls @ 14518us
#
# [19:08:00] MakeCuts: 0.01462s, 1 calls @ 14620us
#
# [19:08:00] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [19:10:15] ======== Monitor (0): Learner ========
# [19:10:15] Configure: 0.000876s, 1 calls @ 876us
#
# [19:10:15] EvalOneIter: 0.002085s, 100 calls @ 2085us
#
# [19:10:15] GetGradient: 0.166406s, 100 calls @ 166406us
#
# [19:10:15] PredictRaw: 0.001384s, 100 calls @ 1384us
#
# [19:10:15] UpdateOneIter: 135.321s, 100 calls @ 135320838us
#
# [19:10:15] ======== Monitor (0): GBTree ========
# [19:10:15] BoostNewTrees: 135.131s, 100 calls @ 135130739us
#
# [19:10:15] CommitModel: 0.000209s, 100 calls @ 209us
#
# [19:10:15] ======== Monitor (0): HistUpdater ========
# [19:10:15] BuildHistogram: 58.8914s, 4508 calls @ 58891422us
#
# [19:10:15] EvaluateSplits: 25.7756s, 4608 calls @ 25775554us
#
# [19:10:15] InitData: 0.336047s, 100 calls @ 336047us
#
# [19:10:15] InitRoot: 27.3844s, 100 calls @ 27384403us
#
# [19:10:15] LeafPartition: 4.8e-05s, 100 calls @ 48us
#
# [19:10:15] UpdatePosition: 20.8525s, 5911 calls @ 20852451us
#
# [19:10:15] UpdatePredictionCache: 0.630645s, 100 calls @ 630645us
#
# [19:10:15] UpdateTree: 134.497s, 100 calls @ 134496818us
#
# [19:10:15] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 5/5] END colsample_bytree=1.0, learning_rate=0.2, max_depth=20, n_estimators=100, subsample=1.0;, score=-17.249 total time= 2.7min
# [19:10:43] ======== Monitor (0): HostSketchContainer ========
# [19:10:43] AllReduce: 0.01855s, 1 calls @ 18550us
#
# [19:10:43] MakeCuts: 0.01868s, 1 calls @ 18680us
#
# [19:10:43] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [19:15:36] ======== Monitor (0): Learner ========
# [19:15:36] Configure: 0.001013s, 1 calls @ 1013us
#
# [19:15:36] EvalOneIter: 0.004066s, 200 calls @ 4066us
#
# [19:15:36] GetGradient: 0.350286s, 200 calls @ 350286us
#
# [19:15:36] PredictRaw: 0.001852s, 200 calls @ 1852us
#
# [19:15:36] UpdateOneIter: 292.495s, 200 calls @ 292494978us
#
# [19:15:36] ======== Monitor (0): GBTree ========
# [19:15:36] BoostNewTrees: 292.109s, 200 calls @ 292108753us
#
# [19:15:36] CommitModel: 0.000423s, 200 calls @ 423us
#
# [19:15:36] ======== Monitor (0): HistUpdater ========
# [19:15:36] BuildHistogram: 119.222s, 11490 calls @ 119221573us
#
# [19:15:36] EvaluateSplits: 67.1103s, 11690 calls @ 67110302us
#
# [19:15:36] InitData: 0.82878s, 200 calls @ 828780us
#
# [19:15:36] InitRoot: 55.5219s, 200 calls @ 55521938us
#
# [19:15:36] LeafPartition: 9.9e-05s, 200 calls @ 99us
#
# [19:15:36] UpdatePosition: 42.4473s, 14685 calls @ 42447277us
#
# [19:15:36] UpdatePredictionCache: 1.33111s, 200 calls @ 1331112us
#
# [19:15:36] UpdateTree: 288.69s, 200 calls @ 288689569us
#
# [19:15:37] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 4/5] END colsample_bytree=1.0, learning_rate=0.2, max_depth=20, n_estimators=200, subsample=0.8;, score=-18.022 total time= 5.8min
# [19:10:11] ======== Monitor (0): HostSketchContainer ========
# [19:10:11] AllReduce: 0.016259s, 1 calls @ 16259us
#
# [19:10:11] MakeCuts: 0.016344s, 1 calls @ 16344us
#
# [19:10:11] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [19:14:31] ======== Monitor (0): Learner ========
# [19:14:31] Configure: 0.000994s, 1 calls @ 994us
#
# [19:14:31] EvalOneIter: 0.004037s, 200 calls @ 4037us
#
# [19:14:31] GetGradient: 0.341611s, 200 calls @ 341611us
#
# [19:14:31] PredictRaw: 0.001431s, 200 calls @ 1431us
#
# [19:14:31] UpdateOneIter: 259.156s, 200 calls @ 259156268us
#
# [19:14:31] ======== Monitor (0): GBTree ========
# [19:14:31] BoostNewTrees: 258.783s, 200 calls @ 258782929us
#
# [19:14:31] CommitModel: 0.000403s, 200 calls @ 403us
#
# [19:14:31] ======== Monitor (0): HistUpdater ========
# [19:14:31] BuildHistogram: 103.911s, 9294 calls @ 103911125us
#
# [19:14:31] EvaluateSplits: 51.4962s, 9494 calls @ 51496166us
#
# [19:14:31] InitData: 0.784105s, 200 calls @ 784105us
#
# [19:14:31] InitRoot: 56.1137s, 200 calls @ 56113723us
#
# [19:14:31] LeafPartition: 0.000113s, 200 calls @ 113us
#
# [19:14:31] UpdatePosition: 40.0863s, 11840 calls @ 40086291us
#
# [19:14:31] UpdatePredictionCache: 1.43936s, 200 calls @ 1439363us
#
# [19:14:31] UpdateTree: 255.159s, 200 calls @ 255159343us
#
# [19:14:32] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 3/5] END colsample_bytree=1.0, learning_rate=0.2, max_depth=20, n_estimators=200, subsample=0.8;, score=-17.899 total time= 5.2min
# [19:15:21] ======== Monitor (0): HostSketchContainer ========
# [19:15:21] AllReduce: 0.016154s, 1 calls @ 16154us
#
# [19:15:21] MakeCuts: 0.016246s, 1 calls @ 16246us
#
# [19:15:21] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [19:24:42] ======== Monitor (0): Learner ========
# [19:24:42] Configure: 0.000924s, 1 calls @ 924us
#
# [19:24:42] EvalOneIter: 0.003915s, 200 calls @ 3915us
#
# [19:24:42] GetGradient: 0.307372s, 200 calls @ 307372us
#
# [19:24:42] PredictRaw: 0.001411s, 200 calls @ 1411us
#
# [19:24:42] UpdateOneIter: 556.487s, 200 calls @ 556487176us
#
# [19:24:42] ======== Monitor (0): GBTree ========
# [19:24:42] BoostNewTrees: 556.145s, 200 calls @ 556144929us
#
# [19:24:42] CommitModel: 0.000402s, 200 calls @ 402us
#
# [19:24:42] ======== Monitor (0): HistUpdater ========
# [19:24:42] BuildHistogram: 236.258s, 28821 calls @ 236258151us
#
# [19:24:42] EvaluateSplits: 194.643s, 29021 calls @ 194643263us
#
# [19:24:42] InitData: 0.851175s, 200 calls @ 851175us
#
# [19:24:42] InitRoot: 55.0972s, 200 calls @ 55097222us
#
# [19:24:42] LeafPartition: 9.4e-05s, 200 calls @ 94us
#
# [19:24:42] UpdatePosition: 56.0987s, 37469 calls @ 56098668us
#
# [19:24:42] UpdatePredictionCache: 1.86544s, 200 calls @ 1865442us
#
# [19:24:42] UpdateTree: 554.273s, 200 calls @ 554272790us
#
# [19:24:42] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 2/5] END colsample_bytree=1.0, learning_rate=0.2, max_depth=20, n_estimators=200, subsample=1.0;, score=-17.809 total time=10.9min
# [19:13:19] ======== Monitor (0): HostSketchContainer ========
# [19:13:19] AllReduce: 0.014763s, 1 calls @ 14763us
#
# [19:13:19] MakeCuts: 0.014841s, 1 calls @ 14841us
#
# [19:13:19] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [19:17:29] ======== Monitor (0): Learner ========
# [19:17:29] Configure: 0.000851s, 1 calls @ 851us
#
# [19:17:29] EvalOneIter: 0.004031s, 200 calls @ 4031us
#
# [19:17:29] GetGradient: 0.360581s, 200 calls @ 360581us
#
# [19:17:29] PredictRaw: 0.001788s, 200 calls @ 1788us
#
# [19:17:29] UpdateOneIter: 249.299s, 200 calls @ 249299276us
#
# [19:17:29] ======== Monitor (0): GBTree ========
# [19:17:29] BoostNewTrees: 248.909s, 200 calls @ 248909118us
#
# [19:17:29] CommitModel: 0.00039s, 200 calls @ 390us
#
# [19:17:29] ======== Monitor (0): HistUpdater ========
# [19:17:29] BuildHistogram: 102.655s, 8848 calls @ 102654911us
#
# [19:17:29] EvaluateSplits: 46.614s, 9048 calls @ 46613976us
#
# [19:17:29] InitData: 0.762404s, 200 calls @ 762404us
#
# [19:17:29] InitRoot: 54.6858s, 200 calls @ 54685823us
#
# [19:17:29] LeafPartition: 0.000107s, 200 calls @ 107us
#
# [19:17:29] UpdatePosition: 38.4759s, 11200 calls @ 38475930us
#
# [19:17:29] UpdatePredictionCache: 1.21437s, 200 calls @ 1214370us
#
# [19:17:29] UpdateTree: 245.634s, 200 calls @ 245633794us
#
# [19:17:29] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 5/5] END colsample_bytree=1.0, learning_rate=0.2, max_depth=20, n_estimators=200, subsample=0.8;, score=-17.965 total time= 4.9min
# [19:18:16] ======== Monitor (0): HostSketchContainer ========
# [19:18:16] AllReduce: 0.016166s, 1 calls @ 16166us
#
# [19:18:16] MakeCuts: 0.016259s, 1 calls @ 16259us
#
# [19:18:16] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [19:27:18] ======== Monitor (0): Learner ========
# [19:27:18] Configure: 0.000827s, 1 calls @ 827us
#
# [19:27:18] EvalOneIter: 0.003919s, 200 calls @ 3919us
#
# [19:27:18] GetGradient: 0.307462s, 200 calls @ 307462us
#
# [19:27:18] PredictRaw: 0.002005s, 200 calls @ 2005us
#
# [19:27:18] UpdateOneIter: 539.452s, 200 calls @ 539452074us
#
# [19:27:18] ======== Monitor (0): GBTree ========
# [19:27:18] BoostNewTrees: 539.117s, 200 calls @ 539117099us
#
# [19:27:18] CommitModel: 0.000405s, 200 calls @ 405us
#
# [19:27:18] ======== Monitor (0): HistUpdater ========
# [19:27:18] BuildHistogram: 228.419s, 28495 calls @ 228418964us
#
# [19:27:18] EvaluateSplits: 185.292s, 28695 calls @ 185292056us
#
# [19:27:18] InitData: 0.942739s, 200 calls @ 942739us
#
# [19:27:18] InitRoot: 54.3217s, 200 calls @ 54321733us
#
# [19:27:18] LeafPartition: 9.9e-05s, 200 calls @ 99us
#
# [19:27:18] UpdatePosition: 57.6978s, 37059 calls @ 57697758us
#
# [19:27:18] UpdatePredictionCache: 2.04716s, 200 calls @ 2047160us
#
# [19:27:18] UpdateTree: 537.064s, 200 calls @ 537063550us
#
# [19:27:19] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 4/5] END colsample_bytree=1.0, learning_rate=0.2, max_depth=20, n_estimators=200, subsample=1.0;, score=-17.821 total time=10.0min
# [19:16:34] ======== Monitor (0): HostSketchContainer ========
# [19:16:34] AllReduce: 0.016832s, 1 calls @ 16832us
#
# [19:16:34] MakeCuts: 0.016911s, 1 calls @ 16911us
#
# [19:16:34] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [19:25:37] ======== Monitor (0): Learner ========
# [19:25:37] Configure: 0.00088s, 1 calls @ 880us
#
# [19:25:37] EvalOneIter: 0.003917s, 200 calls @ 3917us
#
# [19:25:37] GetGradient: 0.308881s, 200 calls @ 308881us
#
# [19:25:37] PredictRaw: 0.001652s, 200 calls @ 1652us
#
# [19:25:37] UpdateOneIter: 539.354s, 200 calls @ 539354345us
#
# [19:25:37] ======== Monitor (0): GBTree ========
# [19:25:37] BoostNewTrees: 539.007s, 200 calls @ 539007438us
#
# [19:25:37] CommitModel: 0.000407s, 200 calls @ 407us
#
# [19:25:37] ======== Monitor (0): HistUpdater ========
# [19:25:37] BuildHistogram: 229.761s, 27999 calls @ 229761148us
#
# [19:25:37] EvaluateSplits: 187.147s, 28199 calls @ 187147370us
#
# [19:25:37] InitData: 0.849713s, 200 calls @ 849713us
#
# [19:25:37] InitRoot: 54.3443s, 200 calls @ 54344269us
#
# [19:25:37] LeafPartition: 0.000116s, 200 calls @ 116us
#
# [19:25:37] UpdatePosition: 53.8677s, 36368 calls @ 53867710us
#
# [19:25:37] UpdatePredictionCache: 2.17866s, 200 calls @ 2178656us
#
# [19:25:37] UpdateTree: 536.822s, 200 calls @ 536822368us
#
# [19:25:37] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 3/5] END colsample_bytree=1.0, learning_rate=0.2, max_depth=20, n_estimators=200, subsample=1.0;, score=-17.800 total time=10.5min
# [19:13:40] ======== Monitor (0): HostSketchContainer ========
# [19:13:40] AllReduce: 0.015766s, 1 calls @ 15766us
#
# [19:13:40] MakeCuts: 0.015844s, 1 calls @ 15844us
#
# [19:13:40] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [19:23:14] ======== Monitor (0): Learner ========
# [19:23:14] Configure: 0.000816s, 1 calls @ 816us
#
# [19:23:14] EvalOneIter: 0.003815s, 200 calls @ 3815us
#
# [19:23:14] GetGradient: 0.340009s, 200 calls @ 340009us
#
# [19:23:14] PredictRaw: 0.001611s, 200 calls @ 1611us
#
# [19:23:14] UpdateOneIter: 567.058s, 200 calls @ 567057779us
#
# [19:23:14] ======== Monitor (0): GBTree ========
# [19:23:14] BoostNewTrees: 566.687s, 200 calls @ 566687154us
#
# [19:23:14] CommitModel: 0.000405s, 200 calls @ 405us
#
# [19:23:14] ======== Monitor (0): HistUpdater ========
# [19:23:14] BuildHistogram: 250.289s, 27873 calls @ 250289265us
#
# [19:23:14] EvaluateSplits: 188.072s, 28073 calls @ 188072489us
#
# [19:23:14] InitData: 0.912767s, 200 calls @ 912767us
#
# [19:23:14] InitRoot: 54.6789s, 200 calls @ 54678896us
#
# [19:23:14] LeafPartition: 0.000103s, 200 calls @ 103us
#
# [19:23:14] UpdatePosition: 59.1718s, 36262 calls @ 59171809us
#
# [19:23:14] UpdatePredictionCache: 2.25298s, 200 calls @ 2252984us
#
# [19:23:14] UpdateTree: 564.428s, 200 calls @ 564427706us
#
# [19:23:14] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 1/5] END colsample_bytree=1.0, learning_rate=0.2, max_depth=20, n_estimators=200, subsample=1.0;, score=-17.763 total time=11.1min
# [19:24:43] ======== Monitor (0): HostSketchContainer ========
# [19:24:43] AllReduce: 0.016827s, 1 calls @ 16827us
#
# [19:24:43] MakeCuts: 0.016945s, 1 calls @ 16945us
#
# [19:24:43] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [19:31:38] ======== Monitor (0): Learner ========
# [19:31:38] Configure: 0.001089s, 1 calls @ 1089us
#
# [19:31:38] EvalOneIter: 0.003672s, 200 calls @ 3672us
#
# [19:31:38] GetGradient: 0.298906s, 200 calls @ 298906us
#
# [19:31:38] PredictRaw: 0.001447s, 200 calls @ 1447us
#
# [19:31:38] UpdateOneIter: 410.618s, 200 calls @ 410618449us
#
# [19:31:38] ======== Monitor (0): GBTree ========
# [19:31:38] BoostNewTrees: 410.293s, 200 calls @ 410292856us
#
# [19:31:38] CommitModel: 0.000387s, 200 calls @ 387us
#
# [19:31:38] ======== Monitor (0): HistUpdater ========
# [19:31:38] BuildHistogram: 185.698s, 26061 calls @ 185697982us
#
# [19:31:38] EvaluateSplits: 124.126s, 26261 calls @ 124125636us
#
# [19:31:38] InitData: 0.694692s, 200 calls @ 694692us
#
# [19:31:38] InitRoot: 49.8757s, 200 calls @ 49875719us
#
# [19:31:38] LeafPartition: 0.000115s, 200 calls @ 115us
#
# [19:31:38] UpdatePosition: 42.2845s, 33718 calls @ 42284523us
#
# [19:31:38] UpdatePredictionCache: 1.44028s, 200 calls @ 1440283us
#
# [19:31:38] UpdateTree: 408.846s, 200 calls @ 408846445us
#
# [19:31:38] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [CV 5/5] END colsample_bytree=1.0, learning_rate=0.2, max_depth=20, n_estimators=200, subsample=1.0;, score=-17.806 total time= 7.9min
# [19:32:31] ======== Monitor (0): HostSketchContainer ========
# [19:32:31] AllReduce: 0.007411s, 1 calls @ 7411us
#
# [19:32:31] MakeCuts: 0.007504s, 1 calls @ 7504us
#
# [19:32:31] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0
# [19:33:49] ======== Monitor (0): Learner ========
# [19:33:49] Configure: 0.001341s, 1 calls @ 1341us
#
# [19:33:49] EvalOneIter: 0.00229s, 100 calls @ 2290us
#
# [19:33:49] GetGradient: 0.0997s, 100 calls @ 99700us
#
# [19:33:49] PredictRaw: 0.001323s, 100 calls @ 1323us
#
# [19:33:49] UpdateOneIter: 76.7871s, 100 calls @ 76787148us
#
# [19:33:49] ======== Monitor (0): GBTree ========
# [19:33:49] BoostNewTrees: 76.621s, 100 calls @ 76621013us
#
# [19:33:49] CommitModel: 0.000196s, 100 calls @ 196us
#
# [19:33:49] ======== Monitor (0): HistUpdater ========
# [19:33:49] BuildHistogram: 36.4575s, 5485 calls @ 36457528us
#
# [19:33:49] EvaluateSplits: 12.6632s, 5585 calls @ 12663237us
#
# [19:33:49] InitData: 0.442847s, 100 calls @ 442847us
#
# [19:33:49] InitRoot: 11.3033s, 100 calls @ 11303285us
#
# [19:33:49] LeafPartition: 7.1e-05s, 100 calls @ 71us
#
# [19:33:49] UpdatePosition: 13.3324s, 7248 calls @ 13332366us
#
# [19:33:49] UpdatePredictionCache: 0.790686s, 100 calls @ 790686us
#
# [19:33:49] UpdateTree: 75.8265s, 100 calls @ 75826501us
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=-1, num_parallel_tree=None,
#                                     random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.8, 1.0],
#                          'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [5, 10, 20],
#                          'n_estimators': [50, 100, 200],
#                          'subsample': [0.8, 1.0]},
#              scoring=make_scorer(smape, greater_is_better=False), verbose=3)

# %%
# Print the best parameters and the corresponding score
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", -grid_search.best_score_)
# Out:
# Best Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 20, 'n_estimators': 100, 'subsample': 1.0}
# Best Score: 16.87632263556181

# %%
# Use the best model to make predictions on the test set
best_xgboost_model = grid_search.best_estimator_
pred_xgboost = best_xgboost_model.predict(x_test)
# Out:
# [19:36:51] DEBUG: /workspace/src/gbm/gbtree.cc:130: Using tree method: 0

# %%
smape_score = smape(y_test, pred_xgboost)

print(f'SMAPE Score: {smape_score}')
# Out:
# SMAPE Score: 16.783327347287013

# %%
from joblib import dump

dump(best_xgboost_model, '/kaggle/working/best_xgboost_model1.joblib')
# Out:
# ['/kaggle/working/best_xgboost_model1.joblib']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.plot(y_test, label='True Values', marker='o')
plt.plot(pred_xgboost, label='Predicted Values', marker='x')

plt.title('True vs. Predicted Values by XGBR')
plt.xlabel('Index ')
plt.ylabel('Traffic')
plt.legend()
plt.show()
